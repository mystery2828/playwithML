# %%
from playwithml import predictor as p

P = p('datasets/iris.csv')
P.do_all(c=True)
# Out:
# Thank you for downloading our package
# You can use the web version of this project on https://playwithml.herokuapp.com
# Contributors Akash C and Ashwin Sharma
#
# Your dataset looks like this
#    sepel_length  sepel_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa
# ...
