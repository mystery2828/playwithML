# %%
from playwithml import predictor as p

P = p('pulse.xlsx')
P.do_all(c=True)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-5-83e5562aaa81> in <module>
#       1 from playwithml import predictor as p
#       2
# ----> 3 P = p('D:/pulse/pulse.xlsx')
#       4 P.do_all(c=True)
#
# D:\playwithML\playwithml.py in __init__(self, df)
#      31
#      32     def __init__(self, df):
# ---> 33         try:
#      34             self.df = pd.read_csv(df, header=0, skip_blank_lines=True,
#      35                                   skipinitialspace=True, encoding='latin-1')
#
# ...
